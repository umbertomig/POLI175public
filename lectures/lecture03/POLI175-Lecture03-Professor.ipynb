# %% [markdown]
# # POLI 175 - Machine Learning for Social Sciences
#
# ## Python Refresh I
#
# ---

# %% [markdown]
# # Data Science with Pandas

# %% [markdown]
# ## Load Pandas
#
# Load pandas is very easy. Provided that the package is installed (if not, check [here](https://pandas.pydata.org/pandas-docs/stable/getting_started/install.html) how to install it), type:

# %%
# My code here
import pandas as pd

# %% [markdown]
# And now, pandas is loaded.
#
# ## Load Data into Python
#
# To start having fun, we need to load data into Python. We can do this in three ways: from a local file, from the internet, and from data typed in the keyboard.
#
# ### From Locale
#
# First, we need to find the working directory. To do that, we need to use the library `os`. To do this you need to:
#
# ```
# import os
# print(os.getcwd())
# ```
#
# Then, you need to put the file in the folder. If you need to change the folder, use the function:
#
# ```
# os.chdir("new_path_here")
# ```

# %% [markdown]
# Now that we know the folder, and the file is there, we can load it:
#
# ```
# dat = pd.read_csv('file_name_here.csv')
# ```
#
# Here I will load CSV files, but Pandas has the ability to load files from other formats, such as Excel, SPSS, R, and others.

# %%
# My code here
import os

# %%
print(os.getcwd())
# Out:
# /Users/umbertomignozzetti/PythonQTM385Class

# %% [markdown]
# ### From the internet
#
# The way we will load here is from the internet.
#
# For example, suppose the following dataset: https://raw.githubusercontent.com/umbertomig/qtm150/master/datasets/PErisk.csv.
#
# To open, we use the `read_csv` command as we did with the locale version.

# %%
# My code here
dat = pd.read_csv('https://raw.githubusercontent.com/umbertomig/qtm150/master/datasets/PErisk.csv')

# %%
dat.head()
# Out:
#       country  courts     barb2  prsexp2  prscorr2      gdpw2
# 0   Argentina       0 -0.720775        1         3   9.690170
# 1   Australia       1 -6.907755        5         4  10.304840
# 2     Austria       1 -4.910337        5         4  10.100940
# 3  Bangladesh       0  0.775975        1         0   8.379768
# 4     Belgium       1 -4.617344        5         4  10.250120

# %% [markdown]
# ### From typing in the keyboard
#
# We can also build a dataset from scratch.
#
# For example, we could build a simple dataset in the following way:
#
# ```
# dat = pd.DataFrame({
#     "v1": ['d1', 'd2', 'd3'],
#     "v2": [1, 2, 3],
#     "v3": ['A', 'B', 'A'],
#     "v4": [2.0, 1.1, 2.2]})
# ```
#
# And this works for small datasets, with the inconvenience of having to type.

# %% [markdown]
# ## Dataset Information
#
# Suppose we have a pandas dataset called `dat`. To make it more realistic, use the following example:
#
# ```
# # For me: PErisk
# dat = pd.read_csv('https://raw.githubusercontent.com/umbertomig/qtm150/master/datasets/PErisk.csv')
#
# # For you: tips
# dat2 = pd.read_csv('https://raw.githubusercontent.com/umbertomig/qtm151/main/datasets/tips.csv')
# ```
#
# If you are having VPN issues, I put the data on Canvas, so you can download it and load from your own computer.

# %%
# My code here
dat = pd.read_csv('https://raw.githubusercontent.com/umbertomig/qtm150/master/datasets/PErisk.csv')
tips = pd.read_csv('https://raw.githubusercontent.com/umbertomig/qtm151/main/datasets/tips.csv')
print(dat.head())
print(tips.head())
# Out:
#       country  courts     barb2  prsexp2  prscorr2      gdpw2
# 0   Argentina       0 -0.720775        1         3   9.690170
# 1   Australia       1 -6.907755        5         4  10.304840
# 2     Austria       1 -4.910337        5         4  10.100940
# 3  Bangladesh       0  0.775975        1         0   8.379768
# 4     Belgium       1 -4.617344        5         4  10.250120
#    obs  totbill   tip sex smoker  day   time  size
# 0    1    16.99  1.01   F     No  Sun  Night     2
# 1    2    10.34  1.66   M     No  Sun  Night     3
# 2    3    21.01  3.50   M     No  Sun  Night     3
# 3    4    23.68  3.31   M     No  Sun  Night     2
# 4    5    24.59  3.61   F     No  Sun  Night     4

# %% [markdown]
# ### .info(.)
#
# This method prints the information about the content of a dataset.
#
# Syntax and Usage: `print(dat.info())`

# %%
# My code here
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   country   62 non-null     object
#  1   courts    62 non-null     int64
#  2   barb2     62 non-null     float64
#  3   prsexp2   62 non-null     int64
#  4   prscorr2  62 non-null     int64
#  5   gdpw2     62 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# ### .head(.)
#
# This method prints the first few observations of the dataset.
#
# Syntax and Usage: `print(dat.head())`

# %%
# My code here
dat.head()
# Out:
#       country  courts     barb2  prsexp2  prscorr2      gdpw2
# 0   Argentina       0 -0.720775        1         3   9.690170
# 1   Australia       1 -6.907755        5         4  10.304840
# 2     Austria       1 -4.910337        5         4  10.100940
# 3  Bangladesh       0  0.775975        1         0   8.379768
# 4     Belgium       1 -4.617344        5         4  10.250120

# %% [markdown]
# ### .shape
#
# This prints the number of rows and columns of a dataset.
#
# Syntax and Usage: `print(dat.shape)`
#
# Note: no parenthesis necessary.

# %%
# My code here
print(dat.shape)
# Out:
# (62, 6)

# %% [markdown]
# ### .describe(.)
#
# This method gives us a few summary statistics of the dataset.
#
# Syntax and Usage: `print(dat.describe())`

# %%
# My code here
dat.describe()
# Out:
#           courts      barb2    prsexp2   prscorr2      gdpw2
# count  62.000000  62.000000  62.000000  62.000000  62.000000
# mean    0.451613  -2.925557   3.274194   2.532258   9.041875
# std     0.501716   2.707211   1.369089   1.501013   0.970264
# min     0.000000  -6.907755   0.000000   0.000000   7.029973
# 25%     0.000000  -4.894882   3.000000   1.250000   8.381027
# 50%     0.000000  -2.353233   3.000000   2.000000   9.185412
# 75%     1.000000  -1.301007   4.000000   4.000000   9.889280
# max     1.000000   2.337425   5.000000   5.000000  10.410180

# %% [markdown]
# ### .values
#
# This prints the observations in the dataset.
#
# Syntax and Usage: `print(dat.values)`
#
# Note: no parenthesis necessary.

# %%
# My code here
print(dat.values)
# Out:
# [['Argentina' 0 -0.7207754 1 3 9.69017]
#  ['Australia' 1 -6.907755 5 4 10.304839999999999]
#  ['Austria' 1 -4.910337 5 4 10.10094]
#  ['Bangladesh' 0 0.7759748000000001 1 0 8.379767999999999]
#  ['Belgium' 1 -4.617344 5 4 10.250119999999999]
#  ['Bolivia' 0 -2.46144 0 0 8.583542999999999]
#  ['Botswana' 1 -1.244868 4 3 8.77771]
#  ['Brazil' 1 -0.45703370000000004 4 3 9.375601]
#  ['Burma' 0 1.604343 3 1 7.0967210000000005]
#  ['Cameroon' 0 -4.229065 3 1 8.120886]
#  ['Canada' 1 -6.907755 5 5 10.41018]
#  ['Chile' 1 -1.542761 3 2 9.261224]
#  ['Colombia' 0 -2.057821 3 2 9.191972999999999]
#  ['Congo-Kinshasa' 0 -2.3232880000000002 1 0 7.095064]
#  ['Costa Rica' 1 -5.090003 3 4 9.167328999999999]
#  ["Cote d'Ivoire" 1 -4.229065 4 2 8.228711]
#  ['Denmark' 1 -6.907755 5 5 10.10651]
#  ['Dominican Republic' 0 -2.378862 2 2 8.899731]
#  ['Ecuador' 1 -1.845337 3 2 9.117786]
#  ['Finland' 1 -6.907755 5 5 10.123669999999999]
#  ['Gambia, The' 0 -1.543332 4 2 7.501082000000001]
#  ['Ghana' 0 -1.011517 2 1 7.597396000000001]
#  ['Greece' 0 -2.0732369999999998 3 3 9.701494]
#  ['Hungary' 1 -0.9041942 4 3 9.35184]
#  ['India' 0 -2.1051040000000003 4 2 7.970049]
#  ['Indonesia' 0 -2.100232 3 0 8.39231]
#  ['Iran' 0 2.337425 0 2 9.368114]
#  ['Ireland' 1 -6.907755 5 4 9.891465]
#  ['Israel' 0 -2.3199959999999997 4 4 10.06777]
#  ['Italy' 1 -6.907755 4 3 10.26078]
#  ['Japan' 1 -6.907755 5 4 9.892022]
#  ['Kenya' 0 -2.327605 2 2 7.619724000000001]
#  ['Korea, South' 0 -2.655795 4 1 9.422787]
#  ['Malawi' 0 -1.469424 3 3 7.029973]
#  ['Malaysia' 1 -3.927949 4 3 9.178953]
#  ['Mexico' 0 -1.657935 2 2 9.661735]
#  ['Morocco' 0 -3.1569580000000004 3 1 8.78048]
#  ['New Zealand' 1 -6.907755 5 5 10.176260000000001]
#  ['Nigeria' 0 0.30010679999999995 1 1 7.68708]
#  ['Norway' 1 -6.907755 5 5 10.29833]
#  ['Papua New Guinea' 1 -2.636158 4 2 8.126517999999999]
#  ['Paraguay' 0 -0.9707628 3 0 8.727616000000001]
#  ['Philippines' 0 -2.9647759999999996 1 1 8.384803999999999]
#  ['Poland' 1 1.317021 3 3 9.0524]
#  ['Portugal' 1 -2.459625 4 3 9.444543]
#  ['Sierra Leone' 0 1.406406 3 1 7.759614]
#  ['Singapore' 1 -4.848516 5 5 9.882724000000001]
#  ['South Africa' 0 -2.17582 3 4 9.191871]
#  ['Spain' 1 -6.907755 5 3 10.04733]
#  ['Sri Lanka' 0 -1.864343 2 2 8.627661]
#  ['Sweden' 1 -6.907755 4 5 10.22434]
#  ['Switzerland' 1 -6.907755 5 5 10.3411]
#  ['Syria' 0 1.725166 1 1 9.664150999999999]
#  ['Thailand' 0 -6.907755 3 2 8.548691999999999]
#  ['Togo' 0 -4.229065 4 1 7.331714999999999]
#  ['Tunisia' 0 -2.5853990000000002 2 2 9.047586]
#  ['Turkey' 0 -2.673243 3 2 8.978912]
#  ['United Kingdom' 1 -6.907755 5 5 10.12727]
#  ['Uruguay' 0 -2.127775 2 2 9.414342]
#  ['Venezuela' 1 0.428845 3 2 9.84882]
#  ['Zambia' 0 0.9658104999999999 3 1 7.726213]
#  ['Zimbabwe' 0 -0.6403214 3 2 7.9658929999999994]]

# %% [markdown]
# ### .columns
#
# This prints the variables information of the dataset.
#
# Syntax and Usage: `print(dat.columns)`
#
# Note: no parenthesis necessary.

# %%
# My code here
print(dat.columns)
# Out:
# Index(['country', 'courts', 'barb2', 'prsexp2', 'prscorr2', 'gdpw2'], dtype='object')

# %% [markdown]
# ### .index
#
# This prints informations about the dataset rows.
#
# Syntax and Usage: `print(dat.index)`
#
# Note: no parenthesis necessary.

# %%
# My code here
print(dat.index)
# Out:
# RangeIndex(start=0, stop=62, step=1)

# %% [markdown]
# **Exercise**: Run the same examples for the dataset `tips`

# %%
## Your answers here!
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   obs      244 non-null    int64
#  1   totbill  244 non-null    float64
#  2   tip      244 non-null    float64
#  3   sex      244 non-null    object
#  4   smoker   244 non-null    object
#  5   day      244 non-null    object
#  6   time     244 non-null    object
#  7   size     244 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 15.4+ KB

# %%
tips.head()
# Out:
#    obs  totbill   tip sex smoker  day   time  size
# 0    1    16.99  1.01   F     No  Sun  Night     2
# 1    2    10.34  1.66   M     No  Sun  Night     3
# 2    3    21.01  3.50   M     No  Sun  Night     3
# 3    4    23.68  3.31   M     No  Sun  Night     2
# 4    5    24.59  3.61   F     No  Sun  Night     4

# %%
tips.values
# Out:
# array([[1, 16.99, 1.01, ..., 'Sun', 'Night', 2],
#        [2, 10.34, 1.66, ..., 'Sun', 'Night', 3],
#        [3, 21.01, 3.5, ..., 'Sun', 'Night', 3],
#        ...,
#        [242, 22.67, 2.0, ..., 'Sat', 'Night', 2],
#        [243, 17.82, 1.75, ..., 'Sat', 'Night', 2],
#        [244, 18.78, 3.0, ..., 'Thu', 'Night', 2]], dtype=object)

# %%
tips.describe()
# Out:
#               obs     totbill         tip        size
# count  244.000000  244.000000  244.000000  244.000000
# mean   122.500000   19.785943    2.998279    2.569672
# std     70.580923    8.902412    1.383638    0.951100
# min      1.000000    3.070000    1.000000    1.000000
# 25%     61.750000   13.347500    2.000000    2.000000
# 50%    122.500000   17.795000    2.900000    2.000000
# 75%    183.250000   24.127500    3.562500    3.000000
# max    244.000000   50.810000   10.000000    6.000000

# %%
tips.columns
# Out:
# Index(['obs', 'totbill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %% [markdown]
# ## Data Manipulation
#
# ### Subsetting variables (columns)
#
# To subset variables the sintax is simple. When it is only one variable:
#
# ```
# dat["var_name"]
# ```
#
# When it is two or more, you need to enclose them in a list:
#
# ```
# dat[["var1", "var2"]]
# ```

# %%
# My code here
dat.head()
# Out:
#       country  courts     barb2  prsexp2  prscorr2      gdpw2
# 0   Argentina       0 -0.720775        1         3   9.690170
# 1   Australia       1 -6.907755        5         4  10.304840
# 2     Austria       1 -4.910337        5         4  10.100940
# 3  Bangladesh       0  0.775975        1         0   8.379768
# 4     Belgium       1 -4.617344        5         4  10.250120

# %%
dat["gdpw2"]
# Out:
# 0      9.690170
# 1     10.304840
# 2     10.100940
# 3      8.379768
# 4     10.250120
#         ...
# 57    10.127270
# 58     9.414342
# 59     9.848820
# 60     7.726213
# 61     7.965893
# Name: gdpw2, Length: 62, dtype: float64

# %%
var = dat["gdpw2"]
print(var)
# Out:
# 0      9.690170
# 1     10.304840
# 2     10.100940
# 3      8.379768
# 4     10.250120
#         ...
# 57    10.127270
# 58     9.414342
# 59     9.848820
# 60     7.726213
# 61     7.965893
# Name: gdpw2, Length: 62, dtype: float64

# %%
dat.head()
# Out:
#       country  courts     barb2  prsexp2  prscorr2      gdpw2
# 0   Argentina       0 -0.720775        1         3   9.690170
# 1   Australia       1 -6.907755        5         4  10.304840
# 2     Austria       1 -4.910337        5         4  10.100940
# 3  Bangladesh       0  0.775975        1         0   8.379768
# 4     Belgium       1 -4.617344        5         4  10.250120

# %%
dat[['country', 'prscorr2', 'gdpw2']]
# Out:
#            country  prscorr2      gdpw2
# 0        Argentina         3   9.690170
# 1        Australia         4  10.304840
# 2          Austria         4  10.100940
# 3       Bangladesh         0   8.379768
# 4          Belgium         4  10.250120
# ..             ...       ...        ...
# 57  United Kingdom         5  10.127270
# 58         Uruguay         2   9.414342
# 59       Venezuela         2   9.848820
# 60          Zambia         1   7.726213
# 61        Zimbabwe         2   7.965893
#
# [62 rows x 3 columns]

# %%
tips['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %% [markdown]
# ### Subsetting cases (rows)
#
# Now, to work with cases, notice that pandas allows us to do vectorized operations. For instance:
#
# ```
# dat["var_name"] > some_number
# ```
#
# Returns True, if the variable is greater than the number, and False otherwise. To subset the dataset, you need to:
#
# ```
# dat[dat["var_name"] > some_number]
# ```
#
# And that's it! For multiple comparisons, the syntax is also easy to use:
#
# ```
# dat[ (dat["v1"] == "some_value") & (dat["v2"] == "some_other_value") ]
# ```
#
# And if we want a command similar to `%in%` in R, we can use the `.isin(.)` method:
#
# ```
# dat[ dat["v1"].isin(["some_value", "some_other_value"]) ]
# ```

# %%
# My code here
dat.head()
# Out:
#       country  courts     barb2  prsexp2  prscorr2      gdpw2
# 0   Argentina       0 -0.720775        1         3   9.690170
# 1   Australia       1 -6.907755        5         4  10.304840
# 2     Austria       1 -4.910337        5         4  10.100940
# 3  Bangladesh       0  0.775975        1         0   8.379768
# 4     Belgium       1 -4.617344        5         4  10.250120

# %%
dat['prsexp2'] > 3
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4      True
#       ...
# 57     True
# 58    False
# 59    False
# 60    False
# 61    False
# Name: prsexp2, Length: 62, dtype: bool

# %%
dat[dat['prsexp2'] > 3]
# Out:
#              country  courts     barb2  prsexp2  prscorr2      gdpw2
# 1          Australia       1 -6.907755        5         4  10.304840
# 2            Austria       1 -4.910337        5         4  10.100940
# 4            Belgium       1 -4.617344        5         4  10.250120
# 6           Botswana       1 -1.244868        4         3   8.777710
# 7             Brazil       1 -0.457034        4         3   9.375601
# 10            Canada       1 -6.907755        5         5  10.410180
# 15     Cote d'Ivoire       1 -4.229065        4         2   8.228711
# 16           Denmark       1 -6.907755        5         5  10.106510
# 19           Finland       1 -6.907755        5         5  10.123670
# 20       Gambia, The       0 -1.543332        4         2   7.501082
# 23           Hungary       1 -0.904194        4         3   9.351840
# 24             India       0 -2.105104        4         2   7.970049
# 27           Ireland       1 -6.907755        5         4   9.891465
# 28            Israel       0 -2.319996        4         4  10.067770
# 29             Italy       1 -6.907755        4         3  10.260780
# 30             Japan       1 -6.907755        5         4   9.892022
# 32      Korea, South       0 -2.655795        4         1   9.422787
# 34          Malaysia       1 -3.927949        4         3   9.178953
# 37       New Zealand       1 -6.907755        5         5  10.176260
# 39            Norway       1 -6.907755        5         5  10.298330
# 40  Papua New Guinea       1 -2.636158        4         2   8.126518
# 44          Portugal       1 -2.459625        4         3   9.444543
# 46         Singapore       1 -4.848516        5         5   9.882724
# 48             Spain       1 -6.907755        5         3  10.047330
# 50            Sweden       1 -6.907755        4         5  10.224340
# 51       Switzerland       1 -6.907755        5         5  10.341100
# 54              Togo       0 -4.229065        4         1   7.331715
# 57    United Kingdom       1 -6.907755        5         5  10.127270

# %%
print(dat.head())
(dat['prsexp2'] > 3) & (dat['courts'] == 1)
# Out:
#       country  courts     barb2  prsexp2  prscorr2      gdpw2
# 0   Argentina       0 -0.720775        1         3   9.690170
# 1   Australia       1 -6.907755        5         4  10.304840
# 2     Austria       1 -4.910337        5         4  10.100940
# 3  Bangladesh       0  0.775975        1         0   8.379768
# 4     Belgium       1 -4.617344        5         4  10.250120
# 0     False
# 1      True
# 2      True
# 3     False
# 4      True
#       ...
# 57     True
# 58    False
# 59    False
# 60    False
# 61    False
# Length: 62, dtype: bool

# %%
dat[(dat['prsexp2'] > 3) & (dat['courts'] == 1)]
# Out:
#              country  courts     barb2  prsexp2  prscorr2      gdpw2
# 1          Australia       1 -6.907755        5         4  10.304840
# 2            Austria       1 -4.910337        5         4  10.100940
# 4            Belgium       1 -4.617344        5         4  10.250120
# 6           Botswana       1 -1.244868        4         3   8.777710
# 7             Brazil       1 -0.457034        4         3   9.375601
# 10            Canada       1 -6.907755        5         5  10.410180
# 15     Cote d'Ivoire       1 -4.229065        4         2   8.228711
# 16           Denmark       1 -6.907755        5         5  10.106510
# 19           Finland       1 -6.907755        5         5  10.123670
# 23           Hungary       1 -0.904194        4         3   9.351840
# 27           Ireland       1 -6.907755        5         4   9.891465
# 29             Italy       1 -6.907755        4         3  10.260780
# 30             Japan       1 -6.907755        5         4   9.892022
# 34          Malaysia       1 -3.927949        4         3   9.178953
# 37       New Zealand       1 -6.907755        5         5  10.176260
# 39            Norway       1 -6.907755        5         5  10.298330
# 40  Papua New Guinea       1 -2.636158        4         2   8.126518
# 44          Portugal       1 -2.459625        4         3   9.444543
# 46         Singapore       1 -4.848516        5         5   9.882724
# 48             Spain       1 -6.907755        5         3  10.047330
# 50            Sweden       1 -6.907755        4         5  10.224340
# 51       Switzerland       1 -6.907755        5         5  10.341100
# 57    United Kingdom       1 -6.907755        5         5  10.127270

# %%
dat['country'].isin(['Brazil', 'Canada', 'Finland'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# Name: country, Length: 62, dtype: bool

# %%
dat[dat['country'].isin(['Brazil', 'Canada', 'Finland'])]
# Out:
#     country  courts     barb2  prsexp2  prscorr2      gdpw2
# 7    Brazil       1 -0.457034        4         3   9.375601
# 10   Canada       1 -6.907755        5         5  10.410180
# 19  Finland       1 -6.907755        5         5  10.123670

# %% [markdown]
# **Exercise**: Filter the `tips` dataset by:
#
# 1. Bills of more than 10 dollars
# 2. Smokers
# 3. Weekend
#
# Do each of these separately, then do all together.

# %%
## Your answers here!
tips.head()
# Out:
#    obs  totbill   tip sex smoker  day   time  size
# 0    1    16.99  1.01   F     No  Sun  Night     2
# 1    2    10.34  1.66   M     No  Sun  Night     3
# 2    3    21.01  3.50   M     No  Sun  Night     3
# 3    4    23.68  3.31   M     No  Sun  Night     2
# 4    5    24.59  3.61   F     No  Sun  Night     4

# %%
more_10_bill = tips['totbill'] > 10
smoker = tips['smoker'] == 'Yes'
weeknd = tips['day'].isin(['Sat', 'Sun'])
print(more_10_bill)
print(smoker)
print(weeknd)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Name: totbill, Length: 244, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240     True
# 241     True
# 242    False
# 243    False
# Name: smoker, Length: 244, dtype: bool
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 239     True
# 240     True
# 241     True
# 242     True
# 243    False
# Name: day, Length: 244, dtype: bool

# %%
tips[more_10_bill]
# Out:
#      obs  totbill   tip sex smoker  day   time  size
# 0      1    16.99  1.01   F     No  Sun  Night     2
# 1      2    10.34  1.66   M     No  Sun  Night     3
# 2      3    21.01  3.50   M     No  Sun  Night     3
# 3      4    23.68  3.31   M     No  Sun  Night     2
# 4      5    24.59  3.61   F     No  Sun  Night     4
# ..   ...      ...   ...  ..    ...  ...    ...   ...
# 239  240    29.03  5.92   M     No  Sat  Night     3
# 240  241    27.18  2.00   F    Yes  Sat  Night     2
# 241  242    22.67  2.00   M    Yes  Sat  Night     2
# 242  243    17.82  1.75   M     No  Sat  Night     2
# 243  244    18.78  3.00   F     No  Thu  Night     2
#
# [227 rows x 8 columns]

# %%
tips[smoker]
# Out:
#      obs  totbill   tip sex smoker  day   time  size
# 56    57    38.01  3.00   M    Yes  Sat  Night     4
# 58    59    11.24  1.76   M    Yes  Sat  Night     2
# 60    61    20.29  3.21   M    Yes  Sat  Night     2
# 61    62    13.81  2.00   M    Yes  Sat  Night     2
# 62    63    11.02  1.98   M    Yes  Sat  Night     2
# ..   ...      ...   ...  ..    ...  ...    ...   ...
# 234  235    15.53  3.00   M    Yes  Sat  Night     2
# 236  237    12.60  1.00   M    Yes  Sat  Night     2
# 237  238    32.83  1.17   M    Yes  Sat  Night     2
# 240  241    27.18  2.00   F    Yes  Sat  Night     2
# 241  242    22.67  2.00   M    Yes  Sat  Night     2
#
# [93 rows x 8 columns]

# %%
tips[weeknd]
# Out:
#      obs  totbill   tip sex smoker  day   time  size
# 0      1    16.99  1.01   F     No  Sun  Night     2
# 1      2    10.34  1.66   M     No  Sun  Night     3
# 2      3    21.01  3.50   M     No  Sun  Night     3
# 3      4    23.68  3.31   M     No  Sun  Night     2
# 4      5    24.59  3.61   F     No  Sun  Night     4
# ..   ...      ...   ...  ..    ...  ...    ...   ...
# 238  239    35.83  4.67   F     No  Sat  Night     3
# 239  240    29.03  5.92   M     No  Sat  Night     3
# 240  241    27.18  2.00   F    Yes  Sat  Night     2
# 241  242    22.67  2.00   M    Yes  Sat  Night     2
# 242  243    17.82  1.75   M     No  Sat  Night     2
#
# [163 rows x 8 columns]

# %%
tips[more_10_bill & smoker & weeknd]
# Out:
#      obs  totbill    tip sex smoker  day   time  size
# 56    57    38.01   3.00   M    Yes  Sat  Night     4
# 58    59    11.24   1.76   M    Yes  Sat  Night     2
# 60    61    20.29   3.21   M    Yes  Sat  Night     2
# 61    62    13.81   2.00   M    Yes  Sat  Night     2
# 62    63    11.02   1.98   M    Yes  Sat  Night     2
# 63    64    18.29   3.76   M    Yes  Sat  Night     4
# 69    70    15.01   2.09   M    Yes  Sat  Night     2
# 72    73    26.86   3.14   F    Yes  Sat  Night     2
# 73    74    25.28   5.00   F    Yes  Sat  Night     2
# 76    77    17.92   3.08   M    Yes  Sat  Night     2
# 102  103    44.30   2.50   F    Yes  Sat  Night     3
# 103  104    22.42   3.48   F    Yes  Sat  Night     2
# 105  106    15.36   1.64   M    Yes  Sat  Night     2
# 106  107    20.49   4.06   M    Yes  Sat  Night     2
# 107  108    25.21   4.29   M    Yes  Sat  Night     2
# 109  110    14.31   4.00   F    Yes  Sat  Night     2
# 164  165    17.51   3.00   F    Yes  Sun  Night     2
# 168  169    10.59   1.61   F    Yes  Sat  Night     2
# 169  170    10.63   2.00   F    Yes  Sat  Night     2
# 170  171    50.81  10.00   M    Yes  Sat  Night     3
# 171  172    15.81   3.16   M    Yes  Sat  Night     2
# 173  174    31.85   3.18   M    Yes  Sun  Night     2
# 174  175    16.82   4.00   M    Yes  Sun  Night     2
# 175  176    32.90   3.11   M    Yes  Sun  Night     2
# 176  177    17.89   2.00   M    Yes  Sun  Night     2
# 177  178    14.48   2.00   M    Yes  Sun  Night     2
# 179  180    34.63   3.55   M    Yes  Sun  Night     2
# 180  181    34.65   3.68   M    Yes  Sun  Night     4
# 181  182    23.33   5.65   M    Yes  Sun  Night     2
# 182  183    45.35   3.50   M    Yes  Sun  Night     3
# 183  184    23.17   6.50   M    Yes  Sun  Night     4
# 184  185    40.55   3.00   M    Yes  Sun  Night     2
# 186  187    20.90   3.50   F    Yes  Sun  Night     3
# 187  188    30.46   2.00   M    Yes  Sun  Night     5
# 188  189    18.15   3.50   F    Yes  Sun  Night     3
# 189  190    23.10   4.00   M    Yes  Sun  Night     3
# 190  191    15.69   1.50   M    Yes  Sun  Night     2
# 206  207    26.59   3.41   M    Yes  Sat  Night     3
# 207  208    38.73   3.00   M    Yes  Sat  Night     4
# 208  209    24.27   2.03   M    Yes  Sat  Night     2
# 209  210    12.76   2.23   F    Yes  Sat  Night     2
# 210  211    30.06   2.00   M    Yes  Sat  Night     3
# 211  212    25.89   5.16   M    Yes  Sat  Night     4
# 213  214    13.27   2.50   F    Yes  Sat  Night     2
# 214  215    28.17   6.50   F    Yes  Sat  Night     3
# 215  216    12.90   1.10   F    Yes  Sat  Night     2
# 216  217    28.15   3.00   M    Yes  Sat  Night     5
# 217  218    11.59   1.50   M    Yes  Sat  Night     2
# 219  220    30.14   3.09   F    Yes  Sat  Night     4
# 229  230    22.12   2.88   F    Yes  Sat  Night     2
# 230  231    24.01   2.00   M    Yes  Sat  Night     4
# 231  232    15.69   3.00   M    Yes  Sat  Night     3
# 234  235    15.53   3.00   M    Yes  Sat  Night     2
# 236  237    12.60   1.00   M    Yes  Sat  Night     2
# 237  238    32.83   1.17   M    Yes  Sat  Night     2
# 240  241    27.18   2.00   F    Yes  Sat  Night     2
# 241  242    22.67   2.00   M    Yes  Sat  Night     2

# %% [markdown]
# ### Simple computations
#
# It is simple to create new variables from older ones.
#
# ```
# # Summing two variables
# dat["my_new_var"] = dat["my_old_var1"] + dat["my_old_var2"]
#
# # Multiplying by a constant
# dat["my_new_var"] = dat["my_old_var1"] * constant
#
# # Apply some numpy function (try to always use numpy functions, as pandas is based on numpy)
# import numpy as np
# dat["my_new_logged_var"] = np.log(dat["my_old_var"])
# ```

# %%
# My code here
dat.head()
# Out:
#       country  courts     barb2  prsexp2  prscorr2      gdpw2
# 0   Argentina       0 -0.720775        1         3   9.690170
# 1   Australia       1 -6.907755        5         4  10.304840
# 2     Austria       1 -4.910337        5         4  10.100940
# 3  Bangladesh       0  0.775975        1         0   8.379768
# 4     Belgium       1 -4.617344        5         4  10.250120

# %%
dat['risk'] = 10 - (dat['prsexp2'] + dat['prscorr2'])
dat.head()
# Out:
#       country  courts     barb2  prsexp2  prscorr2      gdpw2  risk
# 0   Argentina       0 -0.720775        1         3   9.690170     6
# 1   Australia       1 -6.907755        5         4  10.304840     1
# 2     Austria       1 -4.910337        5         4  10.100940     1
# 3  Bangladesh       0  0.775975        1         0   8.379768     9
# 4     Belgium       1 -4.617344        5         4  10.250120     1

# %%
import numpy as np
dat['gdppc'] = np.exp(dat['gdpw2'])
dat.head()
# Out:
#       country  courts     barb2  prsexp2  prscorr2      gdpw2  risk  \
# 0   Argentina       0 -0.720775        1         3   9.690170     6
# 1   Australia       1 -6.907755        5         4  10.304840     1
# 2     Austria       1 -4.910337        5         4  10.100940     1
# 3  Bangladesh       0  0.775975        1         0   8.379768     9
# 4     Belgium       1 -4.617344        5         4  10.250120     1
#
#           gdppc
# 0  16157.990919
# 1  29876.873543
# 2  24365.902611
# 3   4357.997753
# 4  28285.936029

# %% [markdown]
# **Exercise**: In the `tips` dataset, create the variable `prop_tip`, which is the proportion of the tip with relation to the total bill.

# %%
## Your answers here!
tips['prop_tip'] = tips['tip'] / tips['totbill']
tips.describe()
# Out:
#               obs     totbill         tip        size    prop_tip
# count  244.000000  244.000000  244.000000  244.000000  244.000000
# mean   122.500000   19.785943    2.998279    2.569672    0.160803
# std     70.580923    8.902412    1.383638    0.951100    0.061072
# min      1.000000    3.070000    1.000000    1.000000    0.035638
# 25%     61.750000   13.347500    2.000000    2.000000    0.129127
# 50%    122.500000   17.795000    2.900000    2.000000    0.154770
# 75%    183.250000   24.127500    3.562500    3.000000    0.191475
# max    244.000000   50.810000   10.000000    6.000000    0.710345

# %% [markdown]
# ## Statistics
#
# We can easily compute statistics from the data. Here are a few methods that we have available:
#
# | Method           | Description                  |
# |------------------|------------------------------|
# | `.median()`      | Median                       |
# | `.mean()`        | Mean                         |
# | `.min()`         | Minimum                      |
# | `.max()`         | Maximum                      |
# | `.var()`         | Variance                     |
# | `.std()`         | Standard Deviation           |
# | `.sum()`         | Sum values                   |
# | `.mode()`        | More frequent values         |
# | `.quantile(val)` | Quantile value (btw 0 and 1) |

# %%
# My code here
dat.head()
# Out:
#       country  courts     barb2  prsexp2  prscorr2      gdpw2  risk  \
# 0   Argentina       0 -0.720775        1         3   9.690170     6
# 1   Australia       1 -6.907755        5         4  10.304840     1
# 2     Austria       1 -4.910337        5         4  10.100940     1
# 3  Bangladesh       0  0.775975        1         0   8.379768     9
# 4     Belgium       1 -4.617344        5         4  10.250120     1
#
#           gdppc
# 0  16157.990919
# 1  29876.873543
# 2  24365.902611
# 3   4357.997753
# 4  28285.936029

# %%
dat['gdppc'].mean()
# Out:
# 12378.127150748098

# %%
dat['gdppc'].median()
# Out:
# 9754.001199015076

# %%
dat['prsexp2'].mode()
# Out:
# 0    3
# dtype: int64

# %%
dat['gdppc'].quantile(0.25)
# Out:
# 4363.4983113830685

# %%
dat['gdppc'].quantile(0.90)
# Out:
# 27436.642085297528

# %%
dat['gdppc'].quantile(0.10)
# Out:
# 2052.199573919149

# %% [markdown]
# **Exercise**: For the `tips` dataset:
#
# 1. Compute the mean and median of tip
# 2. Compute the mode of day
# 3. Compute the first quartile of the totbill.

# %%
## Your answers here!
print('The mean of tip is: ' + str(tips['tip'].mean()))
# Out:
# The mean of tip is: 2.9982786885245902

# %%
print(tips['tip'].median())
# Out:
# 2.9

# %%
print(tips['day'].mode())
# Out:
# 0    Sat
# dtype: object

# %%
print(tips['totbill'].quantile(0.25))
# Out:
# 13.3475

# %% [markdown]
# **Great job!!!**
